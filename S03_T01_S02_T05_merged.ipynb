# %% [markdown]
# ## Exercici 1

# %%
import numpy as np
import pandas as pd
filepath = "https://raw.githubusercontent.com/leobioinf0/Supervitat_Regressio/main/DelayedFlights25mb.csv"
airlineData = pd.read_csv(filepath, index_col=0)
airlineData
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0       2008      5          13          2   1130.0        1115   1419.0
# 1       2008      5           8          4   1646.0        1640   1748.0
# 2       2008     12          25          4   1619.0        1555   1732.0
# 3       2008      3          20          4   1351.0        1345   1600.0
# 4       2008      2          19          2   1950.0        1935   2102.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 203355  2008      7          21          1   1951.0        1935   2329.0
# 203356  2008      7           9          3   1009.0        1000   1140.0
# 203357  2008      1          10          4   1820.0        1814   1950.0
# 203358  2008      5          23          5   1541.0        1525   1646.0
# 203359  2008     10          10          5   1749.0        1735   1856.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0             1343            AA        283  ...    6.0     15.0          0
# 1             1730            WN       2871  ...    3.0     25.0          0
# 2             1705            WN       1857  ...    5.0     11.0          0
# 3             1535            US        953  ...    4.0     26.0          0
# 4             2050            MQ       4445  ...   11.0     12.0          0
# ...            ...           ...        ...  ...    ...      ...        ...
# 203355        2228            FL         29  ...    6.0     25.0          0
# 203356        1123            DL       1639  ...    4.0     36.0          0
# 203357        1938            OO       5437  ...    5.0     14.0          0
# 203358        1625            WN         28  ...    3.0     13.0          0
# 203359        1840            MQ       3353  ...    7.0      9.0          0
#
#         CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0                      N         0          15.0          0.0     21.0
# 1                      N         0           0.0          0.0     12.0
# 2                      N         0           0.0          0.0      3.0
# 3                      N         0           6.0          0.0     19.0
# 4                      N         0           NaN          NaN      NaN
# ...                  ...       ...           ...          ...      ...
# 203355                 N         0           0.0          0.0     45.0
# 203356                 N         0           9.0          0.0      8.0
# 203357                 N         0           NaN          NaN      NaN
# 203358                 N         0           3.0          0.0      5.0
# 203359                 N         0          14.0          0.0      2.0
#
#         SecurityDelay  LateAircraftDelay
# 0                 0.0                0.0
# 1                 0.0                6.0
# 2                 0.0               24.0
# 3                 0.0                0.0
# 4                 NaN                NaN
# ...               ...                ...
# 203355            0.0               16.0
# 203356            0.0                0.0
# 203357            NaN                NaN
# 203358            0.0               13.0
# 203359            0.0                0.0
#
# [203360 rows x 29 columns]

# %%
airlineData.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
airlineData.shape
# Out:
# (130952, 32)

# %%
airlineData.head() #tidy
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      5          13          2   1130.0        1115   1419.0
# 1  2008      5           8          4   1646.0        1640   1748.0
# 2  2008     12          25          4   1619.0        1555   1732.0
# 3  2008      3          20          4   1351.0        1345   1600.0
# 4  2008      2          19          2   1950.0        1935   2102.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1343            AA        283  ...    6.0     15.0          0
# 1        1730            WN       2871  ...    3.0     25.0          0
# 2        1705            WN       1857  ...    5.0     11.0          0
# 3        1535            US        953  ...    4.0     26.0          0
# 4        2050            MQ       4445  ...   11.0     12.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0                 N         0          15.0          0.0     21.0
# 1                 N         0           0.0          0.0     12.0
# 2                 N         0           0.0          0.0      3.0
# 3                 N         0           6.0          0.0     19.0
# 4                 N         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            0.0                0.0
# 1            0.0                6.0
# 2            0.0               24.0
# 3            0.0                0.0
# 4            NaN                NaN
#
# [5 rows x 29 columns]

# %%
airlineData.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek        DepTime  \
# count  203360.0  203360.000000  203360.000000  203360.000000  203360.000000
# mean     2008.0       6.100983      15.740868       3.982415    1517.889580
# std         0.0       3.482422       8.770308       1.996305     451.833194
# min      2008.0       1.000000       1.000000       1.000000       1.000000
# 25%      2008.0       3.000000       8.000000       2.000000    1202.000000
# 50%      2008.0       6.000000      16.000000       4.000000    1545.000000
# 75%      2008.0       9.000000      23.000000       6.000000    1901.000000
# max      2008.0      12.000000      31.000000       7.000000    2400.000000
#
#           CRSDepTime        ArrTime     CRSArrTime      FlightNum  \
# count  203360.000000  202613.000000  203360.000000  203360.000000
# mean     1467.497605    1608.178172    1632.515450    2191.290465
# std       426.064343     549.514338     466.758026    1948.591921
# min         1.000000       1.000000       0.000000       1.000000
# 25%      1131.000000    1314.000000    1323.000000     613.000000
# 50%      1510.000000    1715.000000    1705.000000    1545.000000
# 75%      1819.000000    2030.000000    2014.000000    3446.000000
# max      2359.000000    2400.000000    2400.000000    9740.000000
#
#        ActualElapsedTime  ...       Distance         TaxiIn        TaxiOut  \
# count      202480.000000  ...  203360.000000  202613.000000  203317.000000
# mean          133.434329  ...     767.265101       6.806770      18.217847
# std            72.117377  ...     575.898821       5.281638      14.389049
# min            15.000000  ...      24.000000       0.000000       0.000000
# 25%            80.000000  ...     339.000000       4.000000      10.000000
# 50%           116.000000  ...     607.000000       6.000000      14.000000
# 75%           165.000000  ...     999.000000       8.000000      21.000000
# max           702.000000  ...    4962.000000     186.000000     356.000000
#
#            Cancelled       Diverted   CarrierDelay   WeatherDelay  \
# count  203360.000000  203360.000000  130952.000000  130952.000000
# mean        0.000290       0.004037      19.158027       3.778102
# std         0.017031       0.063411      44.067153      21.528387
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       2.000000       0.000000
# 75%         0.000000       0.000000      21.000000       0.000000
# max         1.000000       1.000000    1707.000000     756.000000
#
#             NASDelay  SecurityDelay  LateAircraftDelay
# count  130952.000000  130952.000000      130952.000000
# mean       14.864324       0.089277          25.313909
# std        33.963409       1.825905          41.951153
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         1.000000       0.000000           8.000000
# 75%        14.000000       0.000000          33.000000
# max      1357.000000     178.000000         994.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ## Exercici 2

# %% [markdown]
# Resumeix estadísticament les columnes d’interès

# %%
airlineData[["TaxiIn", "TaxiOut"]].describe()
# Out:
#               TaxiIn        TaxiOut
# count  202613.000000  203317.000000
# mean        6.806770      18.217847
# std         5.281638      14.389049
# min         0.000000       0.000000
# 25%         4.000000      10.000000
# 50%         6.000000      14.000000
# 75%         8.000000      21.000000
# max       186.000000     356.000000

# %% [markdown]
# Troba quantes dades faltants hi ha per columna (i elimina'ls)

# %%
airlineData.isnull().sum()
# Out:
# Year                     0
# Month                    0
# DayofMonth               0
# DayOfWeek                0
# DepTime                  0
# CRSDepTime               0
# ArrTime                747
# CRSArrTime               0
# UniqueCarrier            0
# FlightNum                0
# TailNum                  0
# ActualElapsedTime      880
# CRSElapsedTime          19
# AirTime                880
# ArrDelay               880
# DepDelay                 0
# Origin                   0
# Dest                     0
# Distance                 0
# TaxiIn                 747
# TaxiOut                 43
# Cancelled                0
# CancellationCode         0
# Diverted                 0
# CarrierDelay         72408
# WeatherDelay         72408
# NASDelay             72408
# SecurityDelay        72408
# LateAircraftDelay    72408
# dtype: int64

# %%
airlineData.dropna(inplace=True)
pd.DataFrame(airlineData.isnull().sum()).T.rename(index={0:'null values'})
# Out:
#              Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# null values     0      0           0          0        0           0        0
#
#              CRSArrTime  UniqueCarrier  FlightNum  ...  Diverted  \
# null values           0              0          0  ...         0
#
#              CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# null values             0             0         0              0
#
#              LateAircraftDelay  AvgSpeed  TotalDelay  LateArrival  \
# null values                  0         0           0            0
#
#              LateArrival1H
# null values              0
#
# [1 rows x 33 columns]

# %% [markdown]
# Crea columnes noves (velocitat mitjana del vol, si ha arribat tard o no...)

# %%
airlineData["AvgSpeed"] = round(60*airlineData["Distance"]/airlineData["AirTime"]) 

airlineData["TotalDelay"] = airlineData["CarrierDelay"] + airlineData["WeatherDelay"] + airlineData["NASDelay"] + airlineData["SecurityDelay"] + airlineData["LateAircraftDelay"]

airlineData["CRSArrTime"] = airlineData["CRSArrTime"].astype(int)
airlineData["LateArrival"] =  np.where(airlineData["CRSArrTime"] < airlineData["ArrTime"], True, False)

airlineData["LateArrival1H"] = np.where(airlineData["TotalDelay"] >= 60 , True, False)

print("Dataframe after adding new columns:")
airlineData.head()
# Out:
# Dataframe after adding new columns:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      5          13          2   1130.0        1115   1419.0
# 1  2008      5           8          4   1646.0        1640   1748.0
# 2  2008     12          25          4   1619.0        1555   1732.0
# 3  2008      3          20          4   1351.0        1345   1600.0
# 4  2008      2          19          2   1950.0        1935   2102.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... Diverted  CarrierDelay  \
# 0        1343            AA        283  ...        0          15.0
# 1        1730            WN       2871  ...        0           0.0
# 2        1705            WN       1857  ...        0           0.0
# 3        1535            US        953  ...        0           6.0
# 4        2050            MQ       4445  ...        0           NaN
#
#    WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay AvgSpeed  \
# 0           0.0      21.0            0.0                0.0    428.0
# 1           0.0      12.0            0.0                6.0    339.0
# 2           0.0       3.0            0.0               24.0    336.0
# 3           0.0      19.0            0.0                0.0    272.0
# 4           NaN       NaN            NaN                NaN    334.0
#
#   TotalDelay  LateArrival  LateArrival1H
# 0       36.0         True          False
# 1       18.0         True          False
# 2       27.0         True          False
# 3       25.0         True          False
# 4        NaN         True          False
#
# [5 rows x 33 columns]

# %% [markdown]
# Taula de les aerolínies amb més endarreriments acumulats

# %%
airlineData["UniqueCarrier"].unique()
# Out:
# array(['AA', 'WN', 'US', 'NW', 'B6', 'DL', 'EV', 'MQ', 'UA', 'XE', 'YV',
#        'OO', '9E', 'CO', 'OH', 'FL', 'AS', 'F9', 'HA', 'AQ'], dtype=object)

# %%
airlineData["UniqueCarrier"].nunique()
# Out:
# 20

# %%
TotalDelayBYAirline= airlineData.groupby("UniqueCarrier")["TotalDelay"].sum()
TotalDelayBYAirline =TotalDelayBYAirline.sort_values(ascending=False)
TotalDelayBYAirline.head(5)
# Out:
# UniqueCarrier
# WN    1121587.0
# AA     907391.0
# UA     708542.0
# MQ     638876.0
# OO     617467.0
# Name: TotalDelay, dtype: float64

# %% [markdown]
# Quins són els vols més llargs?

# %%
AirTimeSorted =airlineData.sort_values(by = "AirTime", ascending=False)
AirTimeSorted[["FlightNum", "UniqueCarrier", "AirTime"]].head(5)
# Out:
#         FlightNum UniqueCarrier  AirTime
# 98670          15            CO    635.0
# 142357         15            CO    632.0
# 169358         15            CO    629.0
# 99599          15            CO    627.0
# 198446         15            CO    623.0

# %% [markdown]
# I els vols més endarrerits?

# %%
TotalDelaySorted =airlineData.sort_values(by = "TotalDelay", ascending=False)
TotalDelaySorted[["FlightNum", "UniqueCarrier", "TotalDelay"]].head(5)
# Out:
#         FlightNum UniqueCarrier  TotalDelay
# 184822       3538            MQ      1707.0
# 65814        1472            NW      1542.0
# 102289       1743            NW      1490.0
# 80579         624            NW      1359.0
# 175592       1274            AA      1357.0

# %%
airlineData.to_csv("./DelayedFlightsUpdated.csv")

# %% [markdown]
# ## Exercici 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import squarify 
filepath = "https://raw.githubusercontent.com/leobioinf0/Supervitat_Regressio/main/DelayedFlights25mb.csv"
airlineData = pd.read_csv(filepath, index_col=0)
airlineData.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
airlineData.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      5          13          2   1130.0        1115   1419.0
# 1  2008      5           8          4   1646.0        1640   1748.0
# 2  2008     12          25          4   1619.0        1555   1732.0
# 3  2008      3          20          4   1351.0        1345   1600.0
# 4  2008      2          19          2   1950.0        1935   2102.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1343            AA        283  ...    6.0     15.0          0
# 1        1730            WN       2871  ...    3.0     25.0          0
# 2        1705            WN       1857  ...    5.0     11.0          0
# 3        1535            US        953  ...    4.0     26.0          0
# 4        2050            MQ       4445  ...   11.0     12.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0                 N         0          15.0          0.0     21.0
# 1                 N         0           0.0          0.0     12.0
# 2                 N         0           0.0          0.0      3.0
# 3                 N         0           6.0          0.0     19.0
# 4                 N         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            0.0                0.0
# 1            0.0                6.0
# 2            0.0               24.0
# 3            0.0                0.0
# 4            NaN                NaN
#
# [5 rows x 29 columns]

# %%
x = airlineData["UniqueCarrier"]
y = airlineData["UniqueCarrier"].value_counts()

plt.bar(y.index, y.values)

plt.title("Frequency of delays by carrier")
plt.ylabel("Number of delays")
plt.xlabel("Carriers")
plt.savefig("fig1.png")

# %%
airlineData["UniqueCarrier"].value_counts().plot(kind="bar", color='m')

plt.title("Frequency of delays by carrier")
plt.ylabel("Number of delays")
plt.xlabel("Carriers")
plt.savefig("fig2.png")

# %%
##Visualització: Una variable numèrica (ArrDelay)
sns.lineplot(data=airlineData, x="Month", y="ArrDelay")
plt.title("Arrival delays per month")
plt.savefig("fig3.png")

# %%
##Visualització: Una variable numèrica (ArrDelay)
airlineData.value_counts("ArrDelay").plot(kind="hist")

plt.title("Arrival delays")
plt.ylabel("Number of delays")
plt.xlabel("Number of flights")
plt.savefig("fig4.png")

# %%
## Una variable numèrica i una categòrica (ArrDelay i UniqueCarrier)
plt.figure(figsize=(10, 10))
grouped_air = airlineData.groupby("UniqueCarrier")[["ArrDelay"]].sum()
squarify.plot(sizes = grouped_air.values, label=grouped_air.index, alpha= 0.8)
plt.axis("off")
plt.title("Sum of total arrival delays by carrier")     
plt.savefig("fig5.png")

# %%
## Dues variables numèriques (ArrDelay i DepDelay)
y1 = airlineData.groupby("Month")[["ArrDelay"]].sum()
y2 = airlineData.groupby("Month")[["DepDelay"]].sum()
print(y1,y2)
# Out:
#         ArrDelay
# Month
# 1       832404.0
# 2       888043.0
# 3       882086.0
# 4       627868.0
# 5       602032.0
# 6       980956.0
# 7       891986.0
# 8       702595.0
# 9       353973.0
# 10      328909.0
# 11      408297.0
# 12     1031718.0         DepDelay
# Month
# 1       850208.0
# 2       890497.0
# 3       904853.0
# 4       646575.0
# 5       627843.0
# 6       973127.0
# 7       906789.0
# 8       745342.0
# 9       387533.0
# 10      364648.0
# 11      438950.0
# 12     1037907.0

# %%
## Dues variables numèriques (ArrDelay i DepDelay)
sns.set(style="darkgrid")
plt.figure(figsize=(10, 10))

y1 = airlineData.groupby("Month")[["ArrDelay"]].sum()
y2 = airlineData.groupby("Month")[["DepDelay"]].sum()

plt.plot(y1, linestyle ='-', marker ='o',color='green', linewidth=2, label="Arrival delays")
plt.plot(y2, linestyle ='dashed', marker ='o', color='red', linewidth=2, label="Departure delays")

#fig, ax = plt.subplots(2,1, sharex=True)
#ax[0].plot(y1)
#ax[1].plot(y2);

plt.legend() 
plt.xlabel("Months")
plt.ylabel("Total number of delays by month (min)")
plt.savefig("fig6.png")

# %%
## Tres variables (ArrDelay, DepDelay i UniqueCarrier)

sns.set(style="darkgrid")
plt.figure(figsize=(10, 10))

airlineData["ArrDepDelay"] = airlineData["DepDelay"] + airlineData["ArrDelay"]
total = airlineData.groupby("UniqueCarrier")[["ArrDepDelay"]].sum().reset_index()

bar1= sns.barplot(x="UniqueCarrier",  y="ArrDepDelay", data=total, color='darkblue')
bar2 = sns.barplot(x="UniqueCarrier", y="DepDelay", data=airlineData, estimator=sum, ci=None,  color='lightblue')

top_bar = mpatches.Patch(color='darkblue', label="Arrival delay")
bottom_bar = mpatches.Patch(color='lightblue', label="Departure delay")
plt.legend(handles=[top_bar, bottom_bar])

plt.xlabel("Carrier")
plt.ylabel("Time")
plt.show()
plt.savefig("fig7.png")

# %%
#Més de tres variables (ArrDelay, DepDelay, AirTime i UniqueCarrier).
sns.set(style="darkgrid")
data_set_vols = airlineData.sample(n = 100)

fig, ax = plt.subplots(figsize=(11,5))

plot1 = sns.barplot(x="UniqueCarrier", y="ArrDelay", data=data_set_vols , label= "Arrival Delay")
plot2 = sns.barplot(x="UniqueCarrier", y="DepDelay", data=data_set_vols ,label="Departure Delay")
plot3 = sns.barplot(x="UniqueCarrier", y="AirTime" , data=data_set_vols ,label="Air Time")

#labels = airlineData("UniqueCarrier").index
#x = np.arange(len(labels_carrier))

# %%
#Més de tres variables (ArrDelay, DepDelay, AirTime i UniqueCarrier).
data_set_vols = airlineData.sample(n = 100)

sns.set(style="darkgrid")
plt.figure(figsize=(10, 10))

sns.barplot(x="ArrTime", y="ArrDelay", hue="UniqueCarrier", data=data_set_vols )
plt.show()

# %%
#Més de tres variables (ArrDelay, DepDelay, AirTime i UniqueCarrier).
sns.set(style="darkgrid")
plt.figure(figsize=(10, 10))

z1 = airlineData.groupby("UniqueCarrier")[["ArrDelay"]].sum()
z2 = airlineData.groupby("UniqueCarrier")[["DepDelay"]].sum()
z3 = airlineData.groupby("UniqueCarrier")[["AirTime"]].sum()

plt.plot(z1, linestyle ='-', marker ='o',color='blue', linewidth=2, label="Arrival delays")
plt.plot(z2, linestyle ='-', marker ='o', color='purple', linewidth=2, label="Departure delays")
plt.plot(z3, linestyle ='dashed', marker ='o', color='red', linewidth=2, label="Time flight")
plt.savefig("fig8.png")

# %% [markdown]
# ## Exercici 2

# %%
#Exporta els gràfics com imatges o com html.

# %% [markdown]
# ## Exercici 3

# %%
#Integra les visualitzacions gràfiques, en la tasca 5, del Sprint 2.
# !nbmerge S02_T05_Estructures_Dataframe.ipynb  S03_T01_Visualitzacio_exploratoria.ipynb > S03_T01_S02_T05_merged.ipynb
